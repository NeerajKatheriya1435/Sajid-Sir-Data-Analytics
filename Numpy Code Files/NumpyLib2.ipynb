# %%
import numpy as np

# %%
# Data Structures : [Restaurent_id, year 2021, year 2022, year 2023, year 2024,year 2025]
salesData=np.array([
    [101,2000,4000,3000,8000,5000], #1
    [102,4000,7000,3000,8000,3000], #2
    [103,6000,4000,3000,3000,5000],
    [104,2000,3000,6000,8000,7000],
    [105,3000,7000,3000,8000,6000]
    ])

# %%
# Print first three rows
# print("First Three Rows: ",salesData[2:])

#all the sales in 2021 of every item
# print("First Column: ",salesData[:,2])

# all the sales in all year if every item except First Column
print("Except First Column: ",salesData[:,1:])
# Out:
# Except First Column:  [[2000 4000 3000 8000 5000]
#  [4000 7000 3000 8000 3000]
#  [6000 4000 3000 3000 5000]
#  [2000 3000 6000 8000 7000]
#  [3000 7000 3000 8000 6000]]

# %%
# print("Total Sales 2021 Year: ",np.sum(salesData[:,1],axis=0))
# print("Total Sales Per Year: ",np.sum(salesData[:,1:],axis=0))
# print("Total Sales Per Year: ",np.sum(salesData[:,1:],axis=1))
# print("Mininum Sales Of Restaurant (Row): ",np.min(salesData[:,1:],axis=1))
# print("Mininum Sales Of Restaurant (Row): ",np.min(np.sum(salesData[:,1:],axis=1)))
# print("Mininum Sales Of Restaurant (Row): ",np.min(salesData[:,1:],axis=1))
# print("Maximum Sales Per Year (Column): ",np.max(salesData[:,1:],axis=0))
# print("Average Sales Per Restaurant (Row): ",np.mean(salesData[:,1:],axis=0))
print("Cumlative Sales Per Restaurant (Row): ",np.cumsum(salesData[:,1:],axis=1))

# 1,6 9 5

# 1,7, 16,21

# 10, 15,12,16

# 10,25,23,39
# 2021, 2022,2023,2024
# Out:
# Cumlative Sales Per Restaurant (Row):  [[ 2000  6000  9000 17000 22000]
#  [ 4000 11000 14000 22000 25000]
#  [ 6000 10000 13000 16000 21000]
#  [ 2000  5000 11000 19000 26000]
#  [ 3000 10000 13000 21000 27000]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

x=[1,2,3,4]
y=[12,25,34,45]

# plt.plot(x,y)
plt.plot(np.mean(np.cumsum(salesData[:,1:],axis=1),axis=0))

plt.title("Average Sales Per Year")
plt.xlabel("Years")
plt.ylabel("Sales Data")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Vectors Operations

# %%
myArr1=np.array([1,5,9,3,6])
myArr2=np.array([6,8,9,2,5])

print("Addition of Vector: ",(myArr1+myArr2))
print("Multiplication of Vector: ",(myArr1*myArr2))
print("Dot of Vector: ",np.dot(myArr1,myArr2))

myAngle=np.arccos(np.dot(myArr1,myArr2)/((np.linalg.norm(myArr1)*(np.linalg.norm(myArr2)))))
print("Angle: ",myAngle)
# Out:
# Addition of Vector:  [ 7 13 18  5 11]
# Multiplication of Vector:  [ 6 40 81  6 30]
# Dot of Vector:  163
# Angle:  0.42183579372073216

# %%
# myStd=np.array(["Shubham","Shiva","Vandana","Sahu","Khushi"])
# toUpperCase=np.vectorize(str.upper)
# print("Upper Case: ",toUpperCase(myStd))

# var1="shubham"
# print(var1.capitalize())

# %%
arr1=np.array([1,4,2,6,4])
arr2=np.random.rand(4,4)
arr3=np.zeros((3,3))

print("MyArray1: ",arr1)
print("MyArray2: ",arr2)
print("MyArray3: ",arr3)
# Out:
# MyArray1:  [1 4 2 6 4]
# MyArray2:  [[0.08155792 0.21809413 0.28958085 0.2854939 ]
#  [0.91620828 0.20830721 0.46924104 0.83733923]
#  [0.98878154 0.8154882  0.48055817 0.63912989]
#  [0.38185353 0.25276458 0.57515022 0.0870725 ]]
# MyArray3:  [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
save1=np.save("Arr1.npy",arr1)
save2=np.save("Arr2.npy",arr2)
save3=np.save("Arr3.npy",arr3)

# %%
loadArr1=np.load("Arr1.npy")
print(loadArr1)
# Out:
# [1 4 2 6 4]
